# %%
password=input("Read passWord:")

if password=="admin123":
    print("Access Granted")
else:
   print("Access Denied")
# Out:
# Read passWord: 7777
# Access Denied

# %%
age=int(input("users age:"))
if age <13:
    print("Child")
elif age >=13 and age <= 19 :
    print("Teen")
elif age >=20 and age <=59:
    print("Adult")
else:
    peint("Senior")
# Out:
# users age: 20
# Adult

# %%
num =int(input("Enter a number:"))
# Check if positive
if num > 0:
    print("positive")
else:
    print("Not posiyive")
# Check if between 10 and 50 (inclusive)
if 10 <= num <=50:
    print("The number is between 10 and 50 ")
else:
    print("The number is NOT between 10 and 50")
# Out:
# Enter a number: 20
# positive
# The number is between 10 and 50

# %%
color = input ("Enter a color(rad, yellow, green):")
if color != "":
    match color.lower():
        case "rad":
            print("Stop")
        case "yellow":
            print("Get Ready")
        case "green":
            print("Go")
        case _:
            print("Unknown color")
else:
    print("Input cannot be empty")
# Out:
# Enter a color(rad, yellow, green): yellow
# Get Ready

# %%
print("Menu:")
print("1. Additiont")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = input("Choose an option (1_4):")

num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))

match choice:
    case"1":
        print("Result:" , num1 + num2 )
    case"2":
        print("Result:" , num1 - num2 )
    case"3":
        print("Result:" , num1 * num2 )
    case"4":
        if num2 != 0:
            print("Result:", num1 / num2 )
        else: 
            print("Cannot divide by zero")
    case _:
      print("Invalid choice")
# Out:
# Menu:
# 1. Additiont
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Choose an option (1_4): 3
# Enter first number: 1
# Enter second number: 2
# Result: 2.0

# %%
score = int(input("Enter student score:"))
 #pass or Fail 
if score >= 50 : 
    print(" Passed")
else:
    print("Failed")
    #Assign grade 
if score >= 90 :
    grade ="A"
elif score >= 80:
    grade = "B"
elif score >=70:
    grade ="C"
elif score >=50:
    grade = "D"
else:
    grade = "F"
print("Grade:", grade)
#Message using match
match grade :
    case "A":
        print(" Excellent work!")
    case "B":
        print("Very good !")
    case "C":
        print("Good effort")
    case "D":
        print("You passed ")
    case "F":
        print("Better luck next time")
# Out:
# Enter student score: 85
#  Passed
# Grade: B
# Very good !
